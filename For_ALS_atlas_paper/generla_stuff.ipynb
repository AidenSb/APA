# %%
import pandas as pd

# %%
c9als_exc = pd.read_csv('/home/aiden/codes/APA_stuff/post_qual/APA/For_ALS_atlas_paper/C9ALSFTLD_Excitatory_utr_shift_table.tsv',
sep = '\t')
c9als_exc
# Out:
#                                    genomic_feature(s)  population1_pct  \
# STXBP5L:chr3:121114993-121157657:1               UTR3         0.946824
# STXBP1:chr9:127692164-127692814:1                UTR3         0.731167
# CCDC144A:chr17:16761562-16764339:1               UTR3         0.564254
# CCDC144A:chr17:16761131-16762001:1               UTR3         0.499261
# CCDC144A:chr17:16761695-16761899:1               UTR3         0.181684
# ...                                               ...              ...
# AGAP2:chr12:57723761-57724182:-1                 UTR3         0.045790
# CYB561:chr17:63432951-63433551:-1                UTR3         0.054653
# SSX2IP:chr1:84645992-84646484:-1                 UTR3         0.106352
# BAZ2B:chr2:159404717-159412611:-1                UTR3         0.047267
# MAPK10:chr4:86100807-86101227:-1                 UTR3         0.057607
#
#                                     population2_pct        pvalue  \
# ...
