# %%
import pandas as pd 
import numpy as np

# %%
tst = pd.read_csv('/data/APAproject/pre_qual/apatlas/human.PAS.txt', sep='\t')
tst
# Out:
#                  PAS_ID Chromosome  Position Strand   Mean RPM  \
# 0         chr1:564599:+       chr1    564599      +   3.333397
# 1         chr1:564629:+       chr1    564629      +   1.201574
# 2         chr1:564664:+       chr1    564664      +  14.856402
# 3         chr1:564708:+       chr1    564708      +   1.872293
# 4         chr1:564952:+       chr1    564952      +   1.991760
# ...                 ...        ...       ...    ...        ...
# 311589  chrY:27546122:-       chrY  27546122      -   5.550364
# 311590  chrY:28536584:-       chrY  28536584      -   1.619023
# 311591  chrY:28548425:-       chrY  28548425      -   0.809998
# 311592  chrY:28671979:-       chrY  28671979      -   0.985659
# 311593  chrY:28772221:-       chrY  28772221      -  11.041395
#
#        Intron/exon location      Ensemble ID RefSeq Gene ID Gene Symbol  \
# 0               Single exon  ENSG00000225972             na    MTND1P23
# 1               Single exon  ENSG00000225972             na    MTND1P23
# 2               Single exon  ENSG00000225972             na    MTND1P23
# 3               Single exon  ENSG00000225972             na    MTND1P23
# 4               Single exon  ENSG00000225972             na    MTND1P23
# ...                     ...              ...            ...         ...
# 311589           intergenic              NaN            NaN         NaN
# 311590           intergenic              NaN            NaN         NaN
# 311591           intergenic              NaN            NaN         NaN
# 311592           intergenic              NaN            NaN         NaN
# 311593           intergenic              NaN            NaN         NaN
#
#                                                 Gene Name FAMTOM ID  \
# 0       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 1       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 2       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 3       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 4       mitochondrially encoded NADH:ubiquinone oxidor...        na
# ...                                                   ...       ...
# 311589                                                NaN        na
# 311590                                                NaN        na
# 311591                                                NaN        na
# 311592                                                NaN        na
# 311593                                                NaN        na
#
#        FANTOM Category Extension    PAS_type     PSE PAS Signal Conservation  \
# 0                   na        NO  Pseudogene  49.53%      NoPAS           No
# 1                   na        NO  Pseudogene   3.74%      NoPAS           No
# 2                   na        NO  Pseudogene   4.67%      NoPAS           No
# 3                   na        NO  Pseudogene   4.67%      NoPAS           No
# 4                   na       YES  Pseudogene  32.71%      NoPAS           No
# ...                ...       ...         ...     ...        ...          ...
# 311589              na        NO  intergenic  11.21%   OtherPAS           No
# 311590              na        NO  intergenic   3.74%     AUUAAA           No
# 311591              na        NO  intergenic   6.54%   OtherPAS           No
# 311592              na        NO  intergenic   8.41%      Arich           No
# 311593              na        NO  intergenic  60.75%     AAUAAA           No
#
#        intergenic_TE
# 0                 NO
# 1                 NO
# 2                 NO
# 3                 NO
# 4                 NO
# ...              ...
# 311589           YES
# 311590            NO
# 311591           YES
# 311592            NO
# 311593            NO
#
# [311594 rows x 18 columns]

# %%
tst['PAS_type'].value_counts()
# Out:
# Intron             78002
# 3'UTR(M)           76167
# intergenic         61668
# LncRNA(FANTOM5)    51535
# 3'UTR(F)           13623
# 3'UTR(L)           13623
# CDS                 6717
# Pseudogene          6257
# 3'UTR(S)            3158
# 5UTR                 844
# Name: PAS_type, dtype: int64

# %%
# hg19_coordinates = pd.DataFrame([tst['Chromosome'], tst['Position'], tst['Position']])
hg19_coordinates = hg19_coordinates.T 
hg19_coordinates.to_csv('/data/APAproject/pre_qual/apatlas/PolyAdb_3_hg38_coordinates.bed', sep='\t' , index=False)

# %%
## ok read in the failed positions to get rid of them then read in the new positions to attach to the table

failed_positions = pd.read_csv('/data/APAproject/pre_qual/apatlas/failed_hg19_to_hg38_positions.bed', sep='\t')
failed_positions
# Out:
#    chromosome       pos1       pos2
# 0        chr1  120908277  120908277
# 1        chr1  120908277  120908277
# 2        chr1  147919834  147919834
# 3        chr1  149665879  149665879
# 4        chr1  150219070  150219070
# ..        ...        ...        ...
# 71       chrX  142582600  142582600
# 72       chrX  142723951  142723951
# 73       chrX  142715897  142715897
# 74       chrX  149574315  149574315
# 75       chrY   14919272   14919272
#
# [76 rows x 3 columns]

# %%
failed_positions['pos1'] = failed_positions['pos1'].map(str)
failed_positions['identifier'] = failed_positions.chromosome.str.cat(failed_positions.pos1) 
failed_positions
# Out:
#    chromosome       pos1       pos2     identifier
# 0        chr1  120908277  120908277  chr1120908277
# 1        chr1  120908277  120908277  chr1120908277
# 2        chr1  147919834  147919834  chr1147919834
# 3        chr1  149665879  149665879  chr1149665879
# 4        chr1  150219070  150219070  chr1150219070
# ..        ...        ...        ...            ...
# 71       chrX  142582600  142582600  chrX142582600
# 72       chrX  142723951  142723951  chrX142723951
# 73       chrX  142715897  142715897  chrX142715897
# 74       chrX  149574315  149574315  chrX149574315
# 75       chrY   14919272   14919272   chrY14919272
#
# [76 rows x 4 columns]

# %%
tst['pos1'] = tst['Position'].map(str)
tst['identifier'] = tst.Chromosome.str.cat(tst.pos1) 
tst
# Out:
#                  PAS_ID Chromosome  Position Strand   Mean RPM  \
# 0         chr1:564599:+       chr1    564599      +   3.333397
# 1         chr1:564629:+       chr1    564629      +   1.201574
# 2         chr1:564664:+       chr1    564664      +  14.856402
# 3         chr1:564708:+       chr1    564708      +   1.872293
# 4         chr1:564952:+       chr1    564952      +   1.991760
# ...                 ...        ...       ...    ...        ...
# 311589  chrY:27546122:-       chrY  27546122      -   5.550364
# 311590  chrY:28536584:-       chrY  28536584      -   1.619023
# 311591  chrY:28548425:-       chrY  28548425      -   0.809998
# 311592  chrY:28671979:-       chrY  28671979      -   0.985659
# 311593  chrY:28772221:-       chrY  28772221      -  11.041395
#
#        Intron/exon location      Ensemble ID RefSeq Gene ID Gene Symbol  \
# 0               Single exon  ENSG00000225972             na    MTND1P23
# 1               Single exon  ENSG00000225972             na    MTND1P23
# 2               Single exon  ENSG00000225972             na    MTND1P23
# 3               Single exon  ENSG00000225972             na    MTND1P23
# 4               Single exon  ENSG00000225972             na    MTND1P23
# ...                     ...              ...            ...         ...
# 311589           intergenic              NaN            NaN         NaN
# 311590           intergenic              NaN            NaN         NaN
# 311591           intergenic              NaN            NaN         NaN
# 311592           intergenic              NaN            NaN         NaN
# 311593           intergenic              NaN            NaN         NaN
#
#                                                 Gene Name FAMTOM ID  \
# 0       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 1       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 2       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 3       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 4       mitochondrially encoded NADH:ubiquinone oxidor...        na
# ...                                                   ...       ...
# 311589                                                NaN        na
# 311590                                                NaN        na
# 311591                                                NaN        na
# 311592                                                NaN        na
# 311593                                                NaN        na
#
#        FANTOM Category Extension    PAS_type     PSE PAS Signal Conservation  \
# 0                   na        NO  Pseudogene  49.53%      NoPAS           No
# 1                   na        NO  Pseudogene   3.74%      NoPAS           No
# 2                   na        NO  Pseudogene   4.67%      NoPAS           No
# 3                   na        NO  Pseudogene   4.67%      NoPAS           No
# 4                   na       YES  Pseudogene  32.71%      NoPAS           No
# ...                ...       ...         ...     ...        ...          ...
# 311589              na        NO  intergenic  11.21%   OtherPAS           No
# 311590              na        NO  intergenic   3.74%     AUUAAA           No
# 311591              na        NO  intergenic   6.54%   OtherPAS           No
# 311592              na        NO  intergenic   8.41%      Arich           No
# 311593              na        NO  intergenic  60.75%     AAUAAA           No
#
#        intergenic_TE      pos1    identifier
# 0                 NO    564599    chr1564599
# 1                 NO    564629    chr1564629
# 2                 NO    564664    chr1564664
# 3                 NO    564708    chr1564708
# 4                 NO    564952    chr1564952
# ...              ...       ...           ...
# 311589           YES  27546122  chrY27546122
# 311590            NO  28536584  chrY28536584
# 311591           YES  28548425  chrY28548425
# 311592            NO  28671979  chrY28671979
# 311593            NO  28772221  chrY28772221
#
# [311594 rows x 20 columns]

# %%
poly_atlas = tst[~tst.identifier.isin(failed_positions.identifier.values)]
poly_atlas
# Out:
#                  PAS_ID Chromosome  Position Strand   Mean RPM  \
# 0         chr1:564599:+       chr1    564599      +   3.333397
# 1         chr1:564629:+       chr1    564629      +   1.201574
# 2         chr1:564664:+       chr1    564664      +  14.856402
# 3         chr1:564708:+       chr1    564708      +   1.872293
# 4         chr1:564952:+       chr1    564952      +   1.991760
# ...                 ...        ...       ...    ...        ...
# 311589  chrY:27546122:-       chrY  27546122      -   5.550364
# 311590  chrY:28536584:-       chrY  28536584      -   1.619023
# 311591  chrY:28548425:-       chrY  28548425      -   0.809998
# 311592  chrY:28671979:-       chrY  28671979      -   0.985659
# 311593  chrY:28772221:-       chrY  28772221      -  11.041395
#
#        Intron/exon location      Ensemble ID RefSeq Gene ID Gene Symbol  \
# 0               Single exon  ENSG00000225972             na    MTND1P23
# 1               Single exon  ENSG00000225972             na    MTND1P23
# 2               Single exon  ENSG00000225972             na    MTND1P23
# 3               Single exon  ENSG00000225972             na    MTND1P23
# 4               Single exon  ENSG00000225972             na    MTND1P23
# ...                     ...              ...            ...         ...
# 311589           intergenic              NaN            NaN         NaN
# 311590           intergenic              NaN            NaN         NaN
# 311591           intergenic              NaN            NaN         NaN
# 311592           intergenic              NaN            NaN         NaN
# 311593           intergenic              NaN            NaN         NaN
#
#                                                 Gene Name FAMTOM ID  \
# 0       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 1       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 2       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 3       mitochondrially encoded NADH:ubiquinone oxidor...        na
# 4       mitochondrially encoded NADH:ubiquinone oxidor...        na
# ...                                                   ...       ...
# 311589                                                NaN        na
# 311590                                                NaN        na
# 311591                                                NaN        na
# 311592                                                NaN        na
# 311593                                                NaN        na
#
#        FANTOM Category Extension    PAS_type     PSE PAS Signal Conservation  \
# 0                   na        NO  Pseudogene  49.53%      NoPAS           No
# 1                   na        NO  Pseudogene   3.74%      NoPAS           No
# 2                   na        NO  Pseudogene   4.67%      NoPAS           No
# 3                   na        NO  Pseudogene   4.67%      NoPAS           No
# 4                   na       YES  Pseudogene  32.71%      NoPAS           No
# ...                ...       ...         ...     ...        ...          ...
# 311589              na        NO  intergenic  11.21%   OtherPAS           No
# 311590              na        NO  intergenic   3.74%     AUUAAA           No
# 311591              na        NO  intergenic   6.54%   OtherPAS           No
# 311592              na        NO  intergenic   8.41%      Arich           No
# 311593              na        NO  intergenic  60.75%     AAUAAA           No
#
#        intergenic_TE      pos1    identifier
# 0                 NO    564599    chr1564599
# 1                 NO    564629    chr1564629
# 2                 NO    564664    chr1564664
# 3                 NO    564708    chr1564708
# 4                 NO    564952    chr1564952
# ...              ...       ...           ...
# 311589           YES  27546122  chrY27546122
# 311590            NO  28536584  chrY28536584
# 311591           YES  28548425  chrY28548425
# 311592            NO  28671979  chrY28671979
# 311593            NO  28772221  chrY28772221
#
# [311518 rows x 20 columns]

# %%
##read in the converted positions
hg38_coordinates = pd.read_csv('/data/APAproject/pre_qual/apatlas/hglft_genome_2be15_ea7880.bed', sep='\t')
hg38_coordinates
# Out:
#        Chromosome      pos1      pos2
# 0            chr1    629219    629219
# 1            chr1    629249    629249
# 2            chr1    629284    629284
# 3            chr1    629328    629328
# 4            chr1    629572    629572
# ...           ...       ...       ...
# 311513       chrY  25399975  25399975
# 311514       chrY  26390437  26390437
# 311515       chrY  26402278  26402278
# 311516       chrY  26525832  26525832
# 311517       chrY  26626074  26626074
#
# [311518 rows x 3 columns]

# %%
poly_atlas['hg38_pos'] = hg38_coordinates['pos1'].values
poly_atlas
# Out:
# /home/aiden/anaconda3/envs/r_seurat/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#                  PAS_ID Chromosome  Position Strand   Mean RPM  \
# 0         chr1:564599:+       chr1    564599      +   3.333397
# 1         chr1:564629:+       chr1    564629      +   1.201574
# 2         chr1:564664:+       chr1    564664      +  14.856402
# 3         chr1:564708:+       chr1    564708      +   1.872293
# 4         chr1:564952:+       chr1    564952      +   1.991760
# ...                 ...        ...       ...    ...        ...
# 311589  chrY:27546122:-       chrY  27546122      -   5.550364
# 311590  chrY:28536584:-       chrY  28536584      -   1.619023
# 311591  chrY:28548425:-       chrY  28548425      -   0.809998
# 311592  chrY:28671979:-       chrY  28671979      -   0.985659
# 311593  chrY:28772221:-       chrY  28772221      -  11.041395
#
#        Intron/exon location      Ensemble ID RefSeq Gene ID Gene Symbol  \
# 0               Single exon  ENSG00000225972             na    MTND1P23
# 1               Single exon  ENSG00000225972             na    MTND1P23
# 2               Single exon  ENSG00000225972             na    MTND1P23
# 3               Single exon  ENSG00000225972             na    MTND1P23
# 4               Single exon  ENSG00000225972             na    MTND1P23
# ...                     ...              ...            ...         ...
# 311589           intergenic              NaN            NaN         NaN
# 311590           intergenic              NaN            NaN         NaN
# 311591           intergenic              NaN            NaN         NaN
# 311592           intergenic              NaN            NaN         NaN
# 311593           intergenic              NaN            NaN         NaN
#
#                                                 Gene Name  ...  \
# 0       mitochondrially encoded NADH:ubiquinone oxidor...  ...
# 1       mitochondrially encoded NADH:ubiquinone oxidor...  ...
# 2       mitochondrially encoded NADH:ubiquinone oxidor...  ...
# 3       mitochondrially encoded NADH:ubiquinone oxidor...  ...
# 4       mitochondrially encoded NADH:ubiquinone oxidor...  ...
# ...                                                   ...  ...
# 311589                                                NaN  ...
# 311590                                                NaN  ...
# 311591                                                NaN  ...
# 311592                                                NaN  ...
# 311593                                                NaN  ...
#
#        FANTOM Category Extension    PAS_type     PSE PAS Signal Conservation  \
# 0                   na        NO  Pseudogene  49.53%      NoPAS           No
# 1                   na        NO  Pseudogene   3.74%      NoPAS           No
# 2                   na        NO  Pseudogene   4.67%      NoPAS           No
# 3                   na        NO  Pseudogene   4.67%      NoPAS           No
# 4                   na       YES  Pseudogene  32.71%      NoPAS           No
# ...                ...       ...         ...     ...        ...          ...
# 311589              na        NO  intergenic  11.21%   OtherPAS           No
# 311590              na        NO  intergenic   3.74%     AUUAAA           No
# 311591              na        NO  intergenic   6.54%   OtherPAS           No
# 311592              na        NO  intergenic   8.41%      Arich           No
# 311593              na        NO  intergenic  60.75%     AAUAAA           No
#
#        intergenic_TE      pos1    identifier  hg38_pos
# 0                 NO    564599    chr1564599    629219
# 1                 NO    564629    chr1564629    629249
# 2                 NO    564664    chr1564664    629284
# 3                 NO    564708    chr1564708    629328
# 4                 NO    564952    chr1564952    629572
# ...              ...       ...           ...       ...
# 311589           YES  27546122  chrY27546122  25399975
# 311590            NO  28536584  chrY28536584  26390437
# 311591           YES  28548425  chrY28548425  26402278
# 311592            NO  28671979  chrY28671979  26525832
# 311593            NO  28772221  chrY28772221  26626074
#
# [311518 rows x 21 columns]

# %%
poly_atlas.to_csv('/data/APAproject/pre_qual/apatlas/PolyA_db_v3_hg38_mapped.bed', sep='\t')

# %%
### lets read an example annotation table and map it to APA database
polyA_atlas = pd.read_csv('/data/APAproject/pre_qual/apatlas/PolyA_db_v3_hg38_mapped.bed', sep='\t')
peaks = pd.read_csv('/data1/APA/Paul_ALS_Data/sierra_out/ALS_paul_peaks_annotated.txt', sep='\t')
peaks
# Out:
#                                     seqnames      start        end   width  \
# ARGLU1:chr13:106543856-106557719:-1    chr13  106543856  106557719   13864
# DST:chr6:56699737-56852174:-1           chr6   56699737   56852174  152438
# TERF2IP:chr16:75647773-75657331:1      chr16   75647773   75657331    9559
# ZNF708:chr19:21293722-21309554:-1      chr19   21293722   21309554   15833
# KMT2E:chr7:105014280-105062294:1        chr7  105014280  105062294   48015
# ...                                      ...        ...        ...     ...
# TAS2R14:chr12:10948138-10948978:-1     chr12   10948138   10948978     841
# PRH1:chr12:10948138-10948978:-1        chr12   10948138   10948978     841
# ANK2:chr4:112982777-112983569:1         chr4  112982777  112983569     793
# NBPF11:chr1:148127499-148128417:-1      chr1  148127499  148128417     919
# FNBP1:chr9:129920974-129922138:-1       chr9  129920974  129922138    1165
#
#                                     strand       gene_id UTR3 UTR5 intron  \
# ARGLU1:chr13:106543856-106557719:-1      -        ARGLU1  YES  NaN    NaN
# DST:chr6:56699737-56852174:-1            -           DST  NaN  YES    YES
# TERF2IP:chr16:75647773-75657331:1        +       TERF2IP  YES  NaN    NaN
# ZNF708:chr19:21293722-21309554:-1        -        ZNF708  YES  NaN    NaN
# KMT2E:chr7:105014280-105062294:1         +         KMT2E  NaN  YES    YES
# ...                                    ...           ...  ...  ...    ...
# TAS2R14:chr12:10948138-10948978:-1       -  PRH1,TAS2R14  NaN  NaN    YES
# PRH1:chr12:10948138-10948978:-1          -  PRH1,TAS2R14  NaN  NaN    YES
# ANK2:chr4:112982777-112983569:1          +          ANK2  NaN  NaN    YES
# NBPF11:chr1:148127499-148128417:-1       -        NBPF11  NaN  NaN    YES
# FNBP1:chr9:129920974-129922138:-1        -         FNBP1  NaN  NaN    YES
#
#                                     exon  CDS  pA_motif  pA_stretch  \
# ARGLU1:chr13:106543856-106557719:-1  NaN  NaN     False       False
# DST:chr6:56699737-56852174:-1        YES  YES     False       False
# TERF2IP:chr16:75647773-75657331:1    NaN  NaN     False       False
# ZNF708:chr19:21293722-21309554:-1    NaN  NaN     False       False
# KMT2E:chr7:105014280-105062294:1     YES  YES     False       False
# ...                                  ...  ...       ...         ...
# TAS2R14:chr12:10948138-10948978:-1   NaN  NaN     False       False
# PRH1:chr12:10948138-10948978:-1      NaN  NaN     False       False
# ANK2:chr4:112982777-112983569:1      NaN  NaN     False        True
# NBPF11:chr1:148127499-148128417:-1   NaN  NaN     False       False
# FNBP1:chr9:129920974-129922138:-1    NaN  NaN     False       False
#
#                                      pT_stretch         Junctions
# ARGLU1:chr13:106543856-106557719:-1       False  across-junctions
# DST:chr6:56699737-56852174:-1             False  across-junctions
# TERF2IP:chr16:75647773-75657331:1         False  across-junctions
# ZNF708:chr19:21293722-21309554:-1         False  across-junctions
# KMT2E:chr7:105014280-105062294:1          False  across-junctions
# ...                                         ...               ...
# TAS2R14:chr12:10948138-10948978:-1        False      no-junctions
# PRH1:chr12:10948138-10948978:-1           False      no-junctions
# ANK2:chr4:112982777-112983569:1           False      no-junctions
# NBPF11:chr1:148127499-148128417:-1        False      no-junctions
# FNBP1:chr9:129920974-129922138:-1         False      no-junctions
#
# [291409 rows x 15 columns]

# %%
peaks['width'].mean()
# Out:
# 1603.3375839455884

# %%
peaks['width'].median()
# Out:
# 444.0

# %%
max(peaks['width'])
# Out:
# 1109956

# %%
min(peaks['width'])
# Out:
# 5

# %%
min(peaks[peaks['UTR3']=='YES']['width'])
# Out:
# 7

# %%
peaks[peaks['UTR3']=='YES']
# Out:
#                                     seqnames      start        end  width  \
# ARGLU1:chr13:106543856-106557719:-1    chr13  106543856  106557719  13864
# TERF2IP:chr16:75647773-75657331:1      chr16   75647773   75657331   9559
# ZNF708:chr19:21293722-21309554:-1      chr19   21293722   21309554  15833
# KMT2E:chr7:105077148-105091364:1        chr7  105077148  105091364  14217
# REX1BD:chr19:18589507-18592336:1       chr19   18589507   18592336   2830
# ...                                      ...        ...        ...    ...
# TMEM165:chr4:55425535-55426436:1        chr4   55425535   55426436    902
# YWHAB:chr20:44907620-44908280:1        chr20   44907620   44908280    661
# GOLGA8B:chr15:34525631-34526133:-1     chr15   34525631   34526133    503
# USP33:chr1:77711703-77715940:-1         chr1   77711703   77715940   4238
# LIFR:chr5:38476383-38477217:-1          chr5   38476383   38477217    835
#
#                                     strand  gene_id UTR3 UTR5 intron exon  \
# ARGLU1:chr13:106543856-106557719:-1      -   ARGLU1  YES  NaN    NaN  NaN
# TERF2IP:chr16:75647773-75657331:1        +  TERF2IP  YES  NaN    NaN  NaN
# ZNF708:chr19:21293722-21309554:-1        -   ZNF708  YES  NaN    NaN  NaN
# KMT2E:chr7:105077148-105091364:1         +    KMT2E  YES  NaN    NaN  NaN
# REX1BD:chr19:18589507-18592336:1         +   REX1BD  YES  NaN    NaN  NaN
# ...                                    ...      ...  ...  ...    ...  ...
# TMEM165:chr4:55425535-55426436:1         +  TMEM165  YES  NaN    NaN  NaN
# YWHAB:chr20:44907620-44908280:1          +    YWHAB  YES  NaN    NaN  NaN
# GOLGA8B:chr15:34525631-34526133:-1       -  GOLGA8B  YES  NaN    NaN  NaN
# USP33:chr1:77711703-77715940:-1          -    USP33  YES  NaN    NaN  NaN
# LIFR:chr5:38476383-38477217:-1           -     LIFR  YES  NaN    NaN  NaN
#
#                                      CDS  pA_motif  pA_stretch  pT_stretch  \
# ARGLU1:chr13:106543856-106557719:-1  NaN     False       False       False
# TERF2IP:chr16:75647773-75657331:1    NaN     False       False       False
# ZNF708:chr19:21293722-21309554:-1    NaN     False       False       False
# KMT2E:chr7:105077148-105091364:1     NaN     False       False       False
# REX1BD:chr19:18589507-18592336:1     NaN      True       False       False
# ...                                  ...       ...         ...         ...
# TMEM165:chr4:55425535-55426436:1     NaN     False       False       False
# YWHAB:chr20:44907620-44908280:1      NaN     False       False       False
# GOLGA8B:chr15:34525631-34526133:-1   NaN      True       False       False
# USP33:chr1:77711703-77715940:-1      NaN     False       False       False
# LIFR:chr5:38476383-38477217:-1       NaN     False       False       False
#
#                                             Junctions
# ARGLU1:chr13:106543856-106557719:-1  across-junctions
# TERF2IP:chr16:75647773-75657331:1    across-junctions
# ZNF708:chr19:21293722-21309554:-1    across-junctions
# KMT2E:chr7:105077148-105091364:1     across-junctions
# REX1BD:chr19:18589507-18592336:1     across-junctions
# ...                                               ...
# TMEM165:chr4:55425535-55426436:1         no-junctions
# YWHAB:chr20:44907620-44908280:1          no-junctions
# GOLGA8B:chr15:34525631-34526133:-1       no-junctions
# USP33:chr1:77711703-77715940:-1      across-junctions
# LIFR:chr5:38476383-38477217:-1           no-junctions
#
# [48612 rows x 15 columns]

# %%
peaks[peaks['UTR3']=='YES']['gene_id'].nunique()
# Out:
# 13666

# %%
gene_counts = peaks['gene_id'].value_counts()
gene_counts[gene_counts > 1]
# Out:
# DLG2                          744
# CADM2                         725
# IL1RAPL1                      660
# CNTNAP2                       630
# CSMD1                         584
#                              ...
# ZNF467                          2
# H2AFJ                           2
# AC005871.2                      2
# BACH1,BACH1-IT1,AP000240.1      2
# BNIP1                           2
# Name: gene_id, Length: 15636, dtype: int64

# %%
print('genes with one peak on their 3UTR.......', len(gene_counts[gene_counts == 1]))
print('genes with two peaks on their 3UTR.......',len(gene_counts[gene_counts == 2]))
print('genes with three peaks on their 3UTR.......',len(gene_counts[gene_counts == 3]))
print('genes with four peaks on their 3UTR.......',len(gene_counts[gene_counts == 4]))
print('genes with more than four peaks on their 3UTR.......',len(gene_counts[gene_counts > 4]))
# Out:
# genes with one peak on their 3UTR....... 4217
# genes with two peaks on their 3UTR....... 2728
# genes with three peaks on their 3UTR....... 1581
# genes with four peaks on their 3UTR....... 1274
# genes with more than four peaks on their 3UTR....... 10053

# %%
polyA_atlas
# Out:
#         Unnamed: 0           PAS_ID Chromosome  Position Strand   Mean RPM  \
# 0                0    chr1:564599:+       chr1    564599      +   3.333397
# 1                1    chr1:564629:+       chr1    564629      +   1.201574
# 2                2    chr1:564664:+       chr1    564664      +  14.856402
# 3                3    chr1:564708:+       chr1    564708      +   1.872293
# 4                4    chr1:564952:+       chr1    564952      +   1.991760
# ...            ...              ...        ...       ...    ...        ...
# 311513      311589  chrY:27546122:-       chrY  27546122      -   5.550364
# 311514      311590  chrY:28536584:-       chrY  28536584      -   1.619023
# 311515      311591  chrY:28548425:-       chrY  28548425      -   0.809998
# 311516      311592  chrY:28671979:-       chrY  28671979      -   0.985659
# 311517      311593  chrY:28772221:-       chrY  28772221      -  11.041395
#
#        Intron/exon location      Ensemble ID RefSeq Gene ID Gene Symbol  ...  \
# 0               Single exon  ENSG00000225972             na    MTND1P23  ...
# 1               Single exon  ENSG00000225972             na    MTND1P23  ...
# 2               Single exon  ENSG00000225972             na    MTND1P23  ...
# 3               Single exon  ENSG00000225972             na    MTND1P23  ...
# 4               Single exon  ENSG00000225972             na    MTND1P23  ...
# ...                     ...              ...            ...         ...  ...
# 311513           intergenic              NaN            NaN         NaN  ...
# 311514           intergenic              NaN            NaN         NaN  ...
# 311515           intergenic              NaN            NaN         NaN  ...
# 311516           intergenic              NaN            NaN         NaN  ...
# 311517           intergenic              NaN            NaN         NaN  ...
#
#        FANTOM Category Extension    PAS_type     PSE PAS Signal Conservation  \
# 0                   na        NO  Pseudogene  49.53%      NoPAS           No
# 1                   na        NO  Pseudogene   3.74%      NoPAS           No
# 2                   na        NO  Pseudogene   4.67%      NoPAS           No
# 3                   na        NO  Pseudogene   4.67%      NoPAS           No
# 4                   na       YES  Pseudogene  32.71%      NoPAS           No
# ...                ...       ...         ...     ...        ...          ...
# 311513              na        NO  intergenic  11.21%   OtherPAS           No
# 311514              na        NO  intergenic   3.74%     AUUAAA           No
# 311515              na        NO  intergenic   6.54%   OtherPAS           No
# 311516              na        NO  intergenic   8.41%      Arich           No
# 311517              na        NO  intergenic  60.75%     AAUAAA           No
#
#        intergenic_TE      pos1    identifier  hg38_pos
# 0                 NO    564599    chr1564599    629219
# 1                 NO    564629    chr1564629    629249
# 2                 NO    564664    chr1564664    629284
# 3                 NO    564708    chr1564708    629328
# 4                 NO    564952    chr1564952    629572
# ...              ...       ...           ...       ...
# 311513           YES  27546122  chrY27546122  25399975
# 311514            NO  28536584  chrY28536584  26390437
# 311515           YES  28548425  chrY28548425  26402278
# 311516            NO  28671979  chrY28671979  26525832
# 311517            NO  28772221  chrY28772221  26626074
#
# [311518 rows x 22 columns]
